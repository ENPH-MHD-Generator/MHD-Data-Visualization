# %%
from src.MHData import MHData

# %%
data_dir = "./example_data/linearHall_6.vtk"
mhd = MHData(data_dir)

# %%
print(mhd.scalar_values())
print(mhd.vector_values())
print(mhd.mesh_bounds())
print(mhd.mesh_centre())
# Out:
# {'point': ['T_0', 'Uz', 'Uy', 'Bz', 'Ux', 'Bx', 'Jx', 'Potential', 'By', 'JH', 'p_rgh', 'Jz', 'Jy', 'p', 'T'], 'cell': ['cellID', 'T_0', 'Uz', 'Uy', 'Bz', 'Ux', 'Bx', 'Jx', 'Potential', 'By', 'JH', 'p_rgh', 'Jz', 'Jy', 'p', 'T']}
# {'point': ['U', 'U_0', 'electric_field', 'fLorentz', 'J', 'B'], 'cell': ['U', 'U_0', 'electric_field', 'fLorentz', 'J', 'B']}
# BoundsTuple(x_min = 0.0,
#             x_max = 0.20000000298023224,
#             y_min = 0.0,
#             y_max = 0.05000000074505806,
#             z_min = 0.0,
#             z_max = 0.05000000074505806)
# (0.10000000149011612, 0.02500000037252903, 0.02500000037252903)

# %%
mhd.plot()
mhd.plot_2d_colour_map('Potential', mhd.mesh_centre()[2]+0.005)
mhd.plot_2d_colour_map('Potential', mhd.mesh_centre()[2])
mhd.plot_2d_colour_map('Potential', mhd.mesh_centre()[2]-0.005)
mhd.plot_2d_colour_map('Potential', mhd.mesh_centre()[1], normal='y')
mhd.show()
# Out:
# Widget(value='<iframe src="http://localhost:52406/index.html?ui=P_0x2756204b110_3&reconnect=auto" class="pyvis…
